# %%
import os
from dotenv import load_dotenv
from nnsight import CONFIG


load_dotenv()
NDIF_API = os.getenv('NDIF_API')
CONFIG.set_default_api_key(NDIF_API)

# %%
from nnsight import LanguageModel

model_name = "openai-community/gpt2"
model_name = "deepseek-ai/DeepSeek-R1-Distill-Llama-8B"

llm = LanguageModel(model_name)

with llm.trace("The Eiffel Tower is in the city of", remote=True) as runner:

    hidden_states = llm.model.layers[-1].output.save()

    output = llm.output.save()

print(hidden_states)

print(output["logits"])
# Out:
# 2025-04-06 10:34:33,562 7b57252b-f2f5-4eca-baa5-d098e6e54cc3 - RECEIVED: Your job has been received and is waiting approval.
# 2025-04-06 10:34:34,470 7b57252b-f2f5-4eca-baa5-d098e6e54cc3 - APPROVED: Your job was approved and is waiting to be run.
# 2025-04-06 10:34:35,138 7b57252b-f2f5-4eca-baa5-d098e6e54cc3 - RUNNING: Your job has started running.
# 2025-04-06 10:34:37,055 7b57252b-f2f5-4eca-baa5-d098e6e54cc3 - COMPLETED: Your job has been completed.
# ...
# (tensor([[[ 0.8281,  1.2344,  0.5703,  ..., -0.5312,  1.4609,  0.4297],
#          [-0.0078, -0.4805, -1.8125,  ..., -0.6562, -0.3477,  1.0625],
#          [ 0.9727, -1.2812,  0.7656,  ..., -1.2266, -0.7812,  0.9922],
#          ...,
#          [ 0.2158,  1.2578,  0.4707,  ...,  0.0063, -0.6367, -0.4844],
#          [ 1.1719, -0.1553,  0.0430,  ...,  0.4316, -0.3203,  0.6133],
#          [ 0.0684,  0.2559,  0.6367,  ...,  0.9492, -0.1216, -0.3203]]],
#        dtype=torch.bfloat16),)
# ...

# %%
from datasets import load_dataset
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
#%% Loading the dataset
ds = load_dataset("andreuka18/OpenThoughts-10k-DeepSeek-R1")
# Out:
# README.md:   0%|          | 0.00/931 [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/297M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/74.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
print(ds["train"][0]['deepseek_reasoning'])
# Out:
# Okay, I need to solve this programming problem. Let's read the problem carefully.
#
# The problem is about a grid where the participant starts at [1][1] and ends at [N][N]. Each cell has some coins. The participant can move either to the right (same corridor, next cell) or down (next corridor, same cell). The goal is to collect as many coins as possible, but after giving at least C coins to the guard. We need to find the maximum coins left after paying C. If even after collecting all possible coins, the total is less than C, output -1.
#
# Hmm. So the steps are:
#
# 1. Calculate the maximum coins collectible along all possible paths from (1,1) to (n,n). But since the start and end are zero, those cells don't contribute.
# 2. For each test case, subtract C from the maximum coins. If the result is >=0, output it. Else, output -1.
#
# ...

# %%
all
